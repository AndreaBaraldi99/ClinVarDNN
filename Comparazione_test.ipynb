# %% [markdown]
# ##### COMPARAZIONE DEI RISULTATI DEI VARI ALGORITMI DI CLASSIFICAZIONE
# *L'addestramento di ogni modello è stato effettuato unendo i dataset di tutti i cromosomi e campionando casualmente l'80% dei dati per l'addestramento e il restante 20% per il test.
# Le matrici si riferiscono alla previsione dei risultati sui dati di test*

# %%
from IPython.display import Image

# %% [markdown]
# - Gradient Boosting

# %%
Image(filename='GradientBoosting.png')

# %% [markdown]
# - Random Forest

# %%
Image(filename='RandomForest.png')

# %% [markdown]
# - Rete neurale base

# %%
Image(filename='NN_Base.png')

# %% [markdown]
# - Rete neurale con raggruppamento delle labels: (Pathogenic, Likely Pathogenic) e (Benign, Likely Benign)

# %%
Image(filename='NN_Groups.png')

# %% [markdown]
# - Voting Classifier composto da Gradient Boosting, Random Forest e Rete neurale base

# %%
Image(filename='VotingClass_RF_GBM_NN.png')

# %% [markdown]
# - XGBoost

# %%
Image(filename='XGBoost.png')

# %% [markdown]
# - Voting Classifier composto da XGBoost e Random Forest

# %%
Image(filename='VotingClass_RF_XGB.png')
